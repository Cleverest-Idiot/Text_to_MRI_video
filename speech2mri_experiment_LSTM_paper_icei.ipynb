# %%
# '''
# Written by Tamas Gabor Csapo <csapot@tmit.bme.hu>
# First version Jan 21, 2019
# Restructured Jan 21, 2020 - for MRI data
# Keras implementation of Csapó T.G., ,,Speaker dependent acoustic-to-articulatory inversion using real-time MRI of the vocal tract'', accepted at Interspeech 2020
# code for training FC-DNN
# '''

# import numpy as np
# import matplotlib.pyplot as plt
# import scipy.io.wavfile as io_wav
# import os
# import os.path
# import datetime
# import pickle
# import cv2
# import random

# # import vocoder_LSP_sptk

# # do not use all GPU memory
# import tensorflow as tf
# from tensorflow import keras
# from keras.backend import set_session
# import librosa


# from keras.models import Sequential
# from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, UpSampling2D, Reshape, LSTM, TimeDistributed

# from keras.callbacks import EarlyStopping, CSVLogger, ModelCheckpoint
# from keras.metrics import mean_squared_error

# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler, MinMaxScaler

# import subprocess
# from subprocess import run
# import numpy as np
# import scipy.io.wavfile as io_wav

import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as io_wav
import os
import datetime
import pickle
import cv2
import random

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, UpSampling2D, Reshape, LSTM, TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger, ModelCheckpoint
from tensorflow.keras.metrics import MeanSquaredError
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import librosa

import json

# Configure GPU settings (updated for TensorFlow 2.x)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)




# from LipReading with slight modifications
# https://github.com/hassanhub/LipReading/blob/master/codes/data_integration.py
################## VIDEO INPUT ##################
def load_video_3D(path, framesPerSec):

    cap = cv2.VideoCapture(path)
    frameCount = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT ))
    frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH ))
    fps = cap.get(cv2.CAP_PROP_FPS)

    buf = np.empty((frameHeight, frameWidth, frameCount), np.dtype('float32'))
    # make sure that all the videos are the same FPS
    if (np.abs(fps - framesPerSec) > 0.01):
        print('fps:', fps, '(' + path + ')')
        return buf

    buf = np.empty((frameHeight, frameWidth, frameCount), np.dtype('float32'))
    fc = 0
    ret = True

    while (fc < frameCount  and ret):
        ret, frame = cap.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame = frame.astype('float32')
        # min-max scaling to [0-1]
        frame = frame-np.amin(frame)
        # make sure not to divide by zero
        if np.amax(frame) != 0:
            frame = frame/np.amax(frame)
        buf[:,:,fc]=frame
        fc += 1
    cap.release()

    return buf

# convert an array of values into a dataset matrix
# code with modifications from
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
def create_dataset_img_inverse(data_in_X, data_in_Y, look_back=1):
    (dim1_X, dim2_X) = data_in_X.shape
    (dim1_Y, dim2_Y, dim3_Y, dim4_Y) = data_in_Y.shape
    data_out_X = np.empty((dim1_X - look_back - 1, look_back, dim2_X))
    data_out_Y = np.empty((dim1_Y - look_back - 1, dim2_Y, dim3_Y, dim4_Y))
    print(dim1_Y)
    print(dim2_Y)
    print(dim3_Y)
    print(dim4_Y)

    for i in range(dim1_X - look_back - 1):
        for j in range(look_back):
            data_out_X[i, j] = data_in_X[i + j]
        data_out_Y[i] = data_in_Y[i + j]
    return data_out_X, data_out_Y

# load vocoder features,
# or calculate, if they are not available
def get_mgc_lsp_coeff(basefilename):
    print('I am in get mgc')
    # if os.path.isfile(basefilename + '.mgclsp'):
    #     print('I am in if part')
    #     mgc_lsp_coeff = np.fromfile(basefilename + '.mgclsp', dtype=np.float32).reshape(-1, order + 1)
    #     lf0 = np.fromfile(basefilename + '.lf0', dtype=np.float32)
    #     print(mgc_lsp_coeff.shape)
    #     print(lf0.shape)
    # else:
        # print(basefilename)
        #(mgc_lsp_coeff, lf0) = mgc_encode(basefilename, samplingFrequency, frameLength, frameShift, ord0er, alpha, stage)
        # command = 'sox ' + basefilename + '.wav' + ' -t raw -r ' + str(samplingFrequency) + ' - ' + ' | x2x +sf | ' + \
        #       'sptk frame -l ' + str(frameLength) + ' -p ' + str(frameShift) + ' | ' + \
        #       'sptk window -l ' + str(frameLength) + ' -L ' + str(frameLength) + ' -w 0 -n 1 | ' + \
        #       'sptk mgcep -a ' + str(alpha) + ' -c ' + str(stage) + ' -m ' + str(order) + ' -l ' + str(frameLength) + ' -e 1.0E-08 -o 4 | ' + \
        #       'sptk lpc2lsp -m ' + str(order) + ' -s ' + str(samplingFrequency / 1000) + ' -n ' + str(frameLength) + ' -p 8 -d 1.0E-08 > ' + basefilename + '.mgclsp'
        # print(command)
        # run(command, shell=True)
        # mgc_lsp_coeff = np.fromfile(basefilename + '.mgclsp', dtype=np.float32).reshape(-1, order + 1)

    (mgc_lsp_coeff, lf0) = mgc_encode(basefilename, samplingFrequency, frameLength, frameShift, order, alpha, stage)

    return (mgc_lsp_coeff, lf0)


for speaker in ['M2', 'M3', 'F1', 'F2' ]:
    # TODO: modify this according to your data path
    dir_mri = '/content/drive/MyDrive/backup_PhD/database/MRI_USC/data/' + speaker + '/avi/'


    # Parameters of vocoder
    samplingFrequency = 20000
    frameLength = 1024 #
    frameShift = 863 # 43.14 ms at 20000 Hz sampling, correspondong to 23.18 fps (MRI video)
    order = 24
    alpha = 0.42
    stage = 3
    n_mgc = order + 1

    # properties of MRI videos
    framesPerSec = 23.18
    n_width = 68
    n_height = 68

    # context window of LSTM
    n_sequence = 3


    # USC-TIMIT contains 92 files (460 sentences) for each speaker
    # train-valid-test split (random) :
    # - 4 files for valid
    # - 2 files for test
    # - the remaining (86 files) for training
    files_mri = dict()
    mri = dict()
    mgc = dict()
    files_mri['all'] = []
    if os.path.isdir(dir_mri):
        for file in sorted(os.listdir(dir_mri)):
            if ".avi" in file:
                files_mri['all'] += [file]

    # randomize file order
    random.seed(17)
    random.shuffle(files_mri['all'])

    files_mri['valid'] = files_mri['all'][0:4]
    files_mri['test'] = files_mri['all'][4:14]
    files_mri['train'] = files_mri['all'][14:]

    print('valid files', files_mri['valid'])
    print('test files', files_mri['test'])   # ['usctimit_mri_f1_146_150.avi', 'usctimit_mri_f1_441_445.avi']

    for train_valid in ['train', 'valid']:
        n_files = len(files_mri[train_valid])
        n_file = 0
        n_max_mri_frames = n_files * 1000
        mri[train_valid] = np.empty((n_max_mri_frames, n_width, n_height))
        mgc[train_valid] = np.empty((n_max_mri_frames, n_mgc))
        mri_size = 0
        mgc_size = 0

        for file in files_mri[train_valid]:
            try:
                print('starting', train_valid, file)
                mri_data = load_video_3D(dir_mri + file, framesPerSec)
                # print(mri_data.shape)
                # (mgc_lsp_coeff, lf0) = get_mgc_lsp_coeff(dir_mri + file[:-4])
                dir_mri_wav = dir_mri.replace('/avi/','/wav/')
                dir_mri_wav = dir_mri_wav + file[:-4]+'.wav'
                x, sr = librosa.load(dir_mri_wav, sr = samplingFrequency)
                n_fft = frameLength   # window length: 0.02 s
                hop_length = frameShift  #
                # mgc_lsp_coeff = librosa.feature.mfcc(x, sr=sr, n_mfcc=25, hop_length=hop_length, n_fft=n_fft)

                # x, sr = librosa.load(dir_mri_wav, sr=samplingFrequency)
                mgc_lsp_coeff = librosa.feature.mfcc(y=x, sr=sr, n_mfcc=25, hop_length=hop_length, n_fft=n_fft)


                mgc_lsp_coeff = mgc_lsp_coeff.transpose()
                # print(dir_mri + file[:-4])
                # print(mgc_lsp_coeff.shape)
            except ValueError as e:
                print("wrong data, check manually!", e)

            else:
                print('minmax:', np.min(mri_data), np.max(mri_data))
                n_file += 1

                mgc_mri_len = np.min((mri_data.shape[2], len(mgc_lsp_coeff)))

                mri_data = mri_data[:, :, 0:mgc_mri_len]
                mgc_lsp_coeff = mgc_lsp_coeff[0:mgc_mri_len]

                if mri_size + mgc_mri_len > n_max_mri_frames:
                    raise

                for i in range(mgc_mri_len):
                    mri[train_valid][mri_size + i] = mri_data[:, :, i] # original, 68x68
                    mgc[train_valid][mgc_size + i] = mgc_lsp_coeff[i]

                mri_size += mgc_mri_len
                mgc_size += mgc_mri_len

                print('n_frames_all: ', mri_size, 'mgc_size: ', mgc_size)

        mri[train_valid] = mri[train_valid][0 : mri_size].reshape(-1, n_width, n_height, 1)
        mgc[train_valid] = mgc[train_valid][0 : mgc_size]



    # target: min max scaler to [0,1] range
    # already scaled in load_video

    # input: normalization to zero mean, unit variance
    # feature by feature
    mgc_scalers = []
    for i in range(n_mgc):
        mgc_scaler = StandardScaler(with_mean=True, with_std=True)
        mgc_scalers.append(mgc_scaler)
        mgc['train'][:, i] = mgc_scalers[i].fit_transform(mgc['train'][:, i].reshape(-1, 1)).ravel()
        mgc['valid'][:, i] = mgc_scalers[i].transform(mgc['valid'][:, i].reshape(-1, 1)).ravel()

    # restructure for LSTM
    print(mri)
    for train_valid in ['train', 'valid']:
        mgc[train_valid], mri[train_valid] = create_dataset_img_inverse(mgc[train_valid], mri[train_valid], look_back = n_sequence)

        mri[train_valid] = mri[train_valid].reshape(-1, n_width * n_height)

    ### single training
    # ### single training
    # model = Sequential()
    # # mdninput_Lstm = keras.Input(shape=(10,25))

    # # model.add(TimeDistributed(Dense(575, kernel_initializer='normal', activation='relu'))(mdninput_Lstm))
    # model.add(TimeDistributed(Dense(575, kernel_initializer='normal', activation='relu'), input_shape=(10, 25)))
    # model.add(TimeDistributed(Dense(575, kernel_initializer='normal', activation='relu')))
    # model.add(TimeDistributed(Dense(575, kernel_initializer='normal', activation='relu')))

    # model.add(LSTM(575, kernel_initializer='normal', activation='relu', return_sequences=True))
    # model.add(LSTM(575, kernel_initializer='normal', activation='relu', return_sequences=False))

    # model.add(Dense(n_width*n_height, kernel_initializer='normal', activation='linear'))

    # model.build()

    # model.compile(loss='mean_squared_error', optimizer='adam')


    model = Sequential([
        TimeDistributed(Dense(575, activation='relu', kernel_initializer='normal'), input_shape=(10, 25)),
        TimeDistributed(Dense(575, activation='relu', kernel_initializer='normal')),
        TimeDistributed(Dense(575, activation='relu', kernel_initializer='normal')),
        LSTM(575, activation='relu', return_sequences=True),
        LSTM(575, activation='relu', return_sequences=False),
        Dense(n_width * n_height, activation='linear', kernel_initializer='normal')
    ])

    model.compile(loss='mean_squared_error', optimizer='adam')
    # print(model.summary())


    current_date = '{date:%Y-%m-%d_%H-%M-%S}'.format( date=datetime.datetime.now() )
    # os.mkdir('/content/models/')
    model_name = '/content/drive/MyDrive/GAN_based_models/speech2mri/models_speech2mri_2024/SPEECH2MRI_LSTM_5frame_' + speaker + '_' + current_date

    print('starting training', speaker, current_date)

    # # early stopping to avoid over-training
    # # csv logging of loss
    # # save best model
    # callbacks = [EarlyStopping(monitor='val_loss', patience=5, verbose=0), \
    #              CSVLogger(model_name + '.csv', append=True, separator=';'),
    #              ModelCheckpoint(model_name + '_weights.h5', monitor='val_loss')]

    # # early stopping to avoid over-training
    # # csv logging of loss
    # # save best model
    # callbacks = [EarlyStopping(monitor='val_loss', patience=5, verbose=0), \
    #              CSVLogger(model_name + '.csv', append=True, separator=';'),
    #              ModelCheckpoint(model_name + '_weights.h5', monitor='val_loss')]

    # # run training
    # history = model.fit(mgc['train'], mri['train'],
    #                         epochs = 100, batch_size = 128, shuffle = True, verbose = 1,
    #                         validation_data=(mgc['valid'], mri['valid']),
    #                         callbacks=callbacks)

    # Save mgc_scalers to a pickle file
    scaler_filename = model_name + '_mgc_scalers.sav'
    with open(scaler_filename, 'wb') as file:
        pickle.dump(mgc_scalers, file)

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=5),
        CSVLogger(model_name + '.csv', append=True, separator=';'),
        ModelCheckpoint(model_name + '_weights.keras', monitor='val_loss')
    ]


    history = model.fit(mgc['train'], mri['train'], epochs=100, batch_size=128, shuffle=True, validation_data=(mgc['valid'], mri['valid']), callbacks=callbacks)
    print(model.summary())


    # Save the model architecture to a JSON file
    model_json = model.to_json()
    with open(model_name + '_model.json', "w") as json_file:
      json_file.write(model_json)

    # 8.6M parameters
    print(model.summary())

    t = mgc['valid'][0 : 465]
    y_pred = model.predict(t)
    y_true = (mri['valid'][0:465])

    # Calculating the error
    FrameErr = np.zeros((465,1))
    for i in range(465):
      t1 = y_pred[i,:]
      t2 = y_true[i,:]
      terr =np.mean((np.square(t1-t2)))
      FrameErr[i]=terr

    MSErr = np.mean(FrameErr)
    print(MSErr)

    # MSErr_fn = MeanSquaredError(y_pred, y_true)
    # print(np.mean(MSErr_fn))


    # save model
    model_json = model.to_json()
    with open(model_name + '_model.json', "w") as json_file:
        json_file.write(model_json)

    # serialize scalers to pickle
    pickle.dump(mgc_scalers, open(model_name + '_mgc_scalers.sav', 'wb'))

    # save test files
    with open(model_name + '_test_files.txt', 'w') as txt_file:
        for file in files_mri['test']:
            txt_file.write(file + '\n')

    # print('finished training', speaker, current_date)
# Out:
# valid files ['usctimit_mri_m2_081_085.avi', 'usctimit_mri_m2_171_175.avi', 'usctimit_mri_m2_251_255.avi', 'usctimit_mri_m2_401_405.avi']
# test files ['usctimit_mri_m2_441_445.avi', 'usctimit_mri_m2_146_150.avi', 'usctimit_mri_m2_261_265.avi', 'usctimit_mri_m2_121_125.avi', 'usctimit_mri_m2_316_320.avi', 'usctimit_mri_m2_411_415.avi', 'usctimit_mri_m2_101_105.avi', 'usctimit_mri_m2_061_065.avi', 'usctimit_mri_m2_091_095.avi', 'usctimit_mri_m2_396_400.avi']
# starting train usctimit_mri_m2_166_170.avi
# minmax: 0.0 1.0
# n_frames_all:  482 mgc_size:  482
# starting train usctimit_mri_m2_306_310.avi
# minmax: 0.0 1.0
# n_frames_all:  1080 mgc_size:  1080
# starting train usctimit_mri_m2_051_055.avi
# minmax: 0.0 1.0
# n_frames_all:  1614 mgc_size:  1614
# starting train usctimit_mri_m2_056_060.avi
# minmax: 0.0 1.0
# n_frames_all:  2163 mgc_size:  2163
# starting train usctimit_mri_m2_276_280.avi
# minmax: 0.0 1.0
# n_frames_all:  2706 mgc_size:  2706
# starting train usctimit_mri_m2_241_245.avi
# minmax: 0.0 1.0
# n_frames_all:  3207 mgc_size:  3207
# starting train usctimit_mri_m2_021_025.avi
# minmax: 0.0 1.0
# n_frames_all:  3661 mgc_size:  3661
# starting train usctimit_mri_m2_221_225.avi
# minmax: 0.0 1.0
# n_frames_all:  4234 mgc_size:  4234
# starting train usctimit_mri_m2_141_145.avi
# minmax: 0.0 1.0
# n_frames_all:  4873 mgc_size:  4873
# starting train usctimit_mri_m2_361_365.avi
# minmax: 0.0 1.0
# n_frames_all:  5438 mgc_size:  5438
# starting train usctimit_mri_m2_341_345.avi
# minmax: 0.0 1.0
# n_frames_all:  5998 mgc_size:  5998
# starting train usctimit_mri_m2_391_395.avi
# minmax: 0.0 1.0
# n_frames_all:  6652 mgc_size:  6652
# starting train usctimit_mri_m2_031_035.avi
# minmax: 0.0 1.0
# n_frames_all:  7211 mgc_size:  7211
# starting train usctimit_mri_m2_456_460.avi
# minmax: 0.0 1.0
# n_frames_all:  7849 mgc_size:  7849
# starting train usctimit_mri_m2_281_285.avi
# minmax: 0.0 1.0
# n_frames_all:  8567 mgc_size:  8567
# starting train usctimit_mri_m2_011_015.avi
# minmax: 0.0 1.0
# n_frames_all:  9049 mgc_size:  9049
# starting train usctimit_mri_m2_381_385.avi
# minmax: 0.0 1.0
# n_frames_all:  9626 mgc_size:  9626
# starting train usctimit_mri_m2_296_300.avi
# minmax: 0.0 1.0
# n_frames_all:  10337 mgc_size:  10337
# starting train usctimit_mri_m2_206_210.avi
# minmax: 0.0 1.0
# n_frames_all:  10879 mgc_size:  10879
# starting train usctimit_mri_m2_286_290.avi
# minmax: 0.0 1.0
# n_frames_all:  11486 mgc_size:  11486
# starting train usctimit_mri_m2_066_070.avi
# minmax: 0.0 1.0
# n_frames_all:  12029 mgc_size:  12029
# starting train usctimit_mri_m2_416_420.avi
# minmax: 0.0 1.0
# n_frames_all:  12522 mgc_size:  12522
# starting train usctimit_mri_m2_356_360.avi
# minmax: 0.0 1.0
# n_frames_all:  13106 mgc_size:  13106
# starting train usctimit_mri_m2_326_330.avi
# minmax: 0.0 1.0
# n_frames_all:  13818 mgc_size:  13818
# starting train usctimit_mri_m2_426_430.avi
# minmax: 0.0 1.0
# n_frames_all:  14419 mgc_size:  14419
# starting train usctimit_mri_m2_001_005.avi
# minmax: 0.0 1.0
# n_frames_all:  14868 mgc_size:  14868
# starting train usctimit_mri_m2_436_440.avi
# minmax: 0.0 1.0
# n_frames_all:  15451 mgc_size:  15451
# starting train usctimit_mri_m2_236_240.avi
# minmax: 0.0 1.0
# n_frames_all:  16004 mgc_size:  16004
# starting train usctimit_mri_m2_291_295.avi
# minmax: 0.0 1.0
# n_frames_all:  16594 mgc_size:  16594
# starting train usctimit_mri_m2_226_230.avi
# minmax: 0.0 1.0
# n_frames_all:  17099 mgc_size:  17099
# starting train usctimit_mri_m2_431_435.avi
# minmax: 0.0 1.0
# n_frames_all:  17543 mgc_size:  17543
# starting train usctimit_mri_m2_406_410.avi
# minmax: 0.0 1.0
# n_frames_all:  18069 mgc_size:  18069
# starting train usctimit_mri_m2_181_185.avi
# minmax: 0.0 1.0
# n_frames_all:  18650 mgc_size:  18650
# starting train usctimit_mri_m2_116_120.avi
# minmax: 0.0 1.0
# n_frames_all:  19240 mgc_size:  19240
# starting train usctimit_mri_m2_136_140.avi
# minmax: 0.0 1.0
# n_frames_all:  19835 mgc_size:  19835
# starting train usctimit_mri_m2_006_010.avi
# minmax: 0.0 1.0
# n_frames_all:  20300 mgc_size:  20300
# starting train usctimit_mri_m2_106_110.avi
# minmax: 0.0 1.0
# n_frames_all:  20860 mgc_size:  20860
# starting train usctimit_mri_m2_301_305.avi
# minmax: 0.0 1.0
# n_frames_all:  21552 mgc_size:  21552
# starting train usctimit_mri_m2_311_315.avi
# minmax: 0.0 1.0
# n_frames_all:  22287 mgc_size:  22287
# starting train usctimit_mri_m2_371_375.avi
# minmax: 0.0 1.0
# n_frames_all:  22923 mgc_size:  22923
# starting train usctimit_mri_m2_216_220.avi
# minmax: 0.0 1.0
# n_frames_all:  23506 mgc_size:  23506
# starting train usctimit_mri_m2_046_050.avi
# minmax: 0.0 1.0
# n_frames_all:  24116 mgc_size:  24116
# starting train usctimit_mri_m2_446_450.avi
# minmax: 0.0 1.0
# n_frames_all:  24627 mgc_size:  24627
# starting train usctimit_mri_m2_376_380.avi
# minmax: 0.0 1.0
# n_frames_all:  25188 mgc_size:  25188
# starting train usctimit_mri_m2_151_155.avi
# minmax: 0.0 1.0
# n_frames_all:  25835 mgc_size:  25835
# starting train usctimit_mri_m2_271_275.avi
# minmax: 0.0 1.0
# n_frames_all:  26351 mgc_size:  26351
# starting train usctimit_mri_m2_386_390.avi
# minmax: 0.0 1.0
# n_frames_all:  27015 mgc_size:  27015
# starting train usctimit_mri_m2_026_030.avi
# minmax: 0.0 1.0
# n_frames_all:  27564 mgc_size:  27564
# starting train usctimit_mri_m2_336_340.avi
# minmax: 0.0 1.0
# n_frames_all:  28137 mgc_size:  28137
# starting train usctimit_mri_m2_196_200.avi
# minmax: 0.0 1.0
# n_frames_all:  28713 mgc_size:  28713
# starting train usctimit_mri_m2_041_045.avi
# minmax: 0.0 1.0
# n_frames_all:  29307 mgc_size:  29307
# starting train usctimit_mri_m2_076_080.avi
# minmax: 0.0 1.0
# n_frames_all:  29825 mgc_size:  29825
# starting train usctimit_mri_m2_211_215.avi
# minmax: 0.0 1.0
# n_frames_all:  30311 mgc_size:  30311
# starting train usctimit_mri_m2_131_135.avi
# minmax: 0.0 1.0
# n_frames_all:  30933 mgc_size:  30933
# starting train usctimit_mri_m2_096_100.avi
# minmax: 0.0 1.0
# n_frames_all:  31470 mgc_size:  31470
# starting train usctimit_mri_m2_126_130.avi
# minmax: 0.0 1.0
# n_frames_all:  32040 mgc_size:  32040
# starting train usctimit_mri_m2_366_370.avi
# minmax: 0.0 1.0
# n_frames_all:  32652 mgc_size:  32652
# starting train usctimit_mri_m2_036_040.avi
# minmax: 0.0 1.0
# n_frames_all:  33232 mgc_size:  33232
# starting train usctimit_mri_m2_351_355.avi
# minmax: 0.0 1.0
# n_frames_all:  33846 mgc_size:  33846
# starting train usctimit_mri_m2_086_090.avi
# minmax: 0.0 1.0
# n_frames_all:  34402 mgc_size:  34402
# starting train usctimit_mri_m2_256_260.avi
# minmax: 0.0 1.0
# n_frames_all:  35036 mgc_size:  35036
# starting train usctimit_mri_m2_201_205.avi
# minmax: 0.0 1.0
# n_frames_all:  35566 mgc_size:  35566
# starting train usctimit_mri_m2_321_325.avi
# minmax: 0.0 1.0
# n_frames_all:  36135 mgc_size:  36135
# starting train usctimit_mri_m2_161_165.avi
# minmax: 0.0 1.0
# n_frames_all:  36711 mgc_size:  36711
# starting train usctimit_mri_m2_451_455.avi
# minmax: 0.0 1.0
# n_frames_all:  37361 mgc_size:  37361
# starting train usctimit_mri_m2_246_250.avi
# minmax: 0.0 1.0
# n_frames_all:  37879 mgc_size:  37879
# starting train usctimit_mri_m2_156_160.avi
# minmax: 0.0 1.0
# n_frames_all:  38538 mgc_size:  38538
# starting train usctimit_mri_m2_016_020.avi
# minmax: 0.0 1.0
# n_frames_all:  38988 mgc_size:  38988
# starting train usctimit_mri_m2_071_075.avi
# minmax: 0.0 1.0
# n_frames_all:  39581 mgc_size:  39581
# starting train usctimit_mri_m2_176_180.avi
# minmax: 0.0 1.0
# n_frames_all:  40027 mgc_size:  40027
# starting train usctimit_mri_m2_421_425.avi
# minmax: 0.0 1.0
# n_frames_all:  40548 mgc_size:  40548
# starting train usctimit_mri_m2_346_350.avi
# minmax: 0.0 1.0
# n_frames_all:  41106 mgc_size:  41106
# starting train usctimit_mri_m2_111_115.avi
# minmax: 0.0 1.0
# n_frames_all:  41589 mgc_size:  41589
# starting train usctimit_mri_m2_186_190.avi
# minmax: 0.0 1.0
# n_frames_all:  42185 mgc_size:  42185
# starting train usctimit_mri_m2_231_235.avi
# minmax: 0.0 1.0
# n_frames_all:  42720 mgc_size:  42720
# starting train usctimit_mri_m2_191_195.avi
# minmax: 0.0 1.0
# n_frames_all:  43320 mgc_size:  43320
# starting train usctimit_mri_m2_266_270.avi
# minmax: 0.0 1.0
# n_frames_all:  43901 mgc_size:  43901
# starting train usctimit_mri_m2_331_335.avi
# minmax: 0.0 1.0
# n_frames_all:  44585 mgc_size:  44585
# starting valid usctimit_mri_m2_081_085.avi
# minmax: 0.0 1.0
# n_frames_all:  524 mgc_size:  524
# starting valid usctimit_mri_m2_171_175.avi
# minmax: 0.0 1.0
# n_frames_all:  1036 mgc_size:  1036
# starting valid usctimit_mri_m2_251_255.avi
# minmax: 0.0 1.0
# n_frames_all:  1676 mgc_size:  1676
# starting valid usctimit_mri_m2_401_405.avi
# minmax: 0.0 1.0
# n_frames_all:  2281 mgc_size:  2281
# {'train': array([[[[0.03149606],
#          [0.02755906],
#          [0.02755906],
#          ...,
#          [0.03937008],
#          [0.03543307],
#          [0.03937008]],
#
#         [[0.03937008],
#          [0.02362205],
#          [0.01181102],
#          ...,
#          [0.03149606],
#          [0.03149606],
#          [0.03543307]],
#
#         [[0.01968504],
#          [0.03937008],
#          [0.02755906],
#          ...,
#          [0.04724409],
#          [0.03937008],
#          [0.02755906]],
#
#         ...,
#
#         [[0.03149606],
#          [0.01968504],
#          [0.03149606],
#          ...,
#          [0.09055118],
#          [0.05905512],
#          [0.0511811 ]],
#
#         [[0.02362205],
#          [0.01968504],
#          [0.03149606],
#          ...,
#          [0.09842519],
#          [0.07086615],
#          [0.04330709]],
#
#         [[0.03543307],
#          [0.03543307],
#          [0.02755906],
#          ...,
#          [0.04724409],
#          [0.08267716],
#          [0.04724409]]],
#
#
#        [[[0.02755906],
#          [0.03543307],
#          [0.01181102],
#          ...,
#          [0.02362205],
#          [0.03543307],
#          [0.04330709]],
#
#         [[0.03543307],
#          [0.03149606],
#          [0.01968504],
#          ...,
#          [0.04330709],
#          [0.03543307],
#          [0.03149606]],
#
#         [[0.00787402],
#          [0.03937008],
#          [0.01181102],
#          ...,
#          [0.03937008],
#          [0.03543307],
#          [0.02362205]],
#
#         ...,
#
#         [[0.02755906],
#          [0.01181102],
#          [0.03937008],
#          ...,
#          [0.08661418],
#          [0.07480315],
#          [0.03149606]],
#
#         [[0.02755906],
#          [0.01181102],
#          [0.02362205],
#          ...,
#          [0.09055118],
#          [0.07874016],
#          [0.03149606]],
#
#         [[0.02362205],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.04330709],
#          [0.08661418],
#          [0.04330709]]],
#
#
#        [[[0.01581028],
#          [0.02371541],
#          [0.00790514],
#          ...,
#          [0.02371541],
#          [0.02371541],
#          [0.04743083]],
#
#         [[0.01976285],
#          [0.02371541],
#          [0.00395257],
#          ...,
#          [0.04347826],
#          [0.02371541],
#          [0.02766798]],
#
#         [[0.00790514],
#          [0.03952569],
#          [0.01581028],
#          ...,
#          [0.04347826],
#          [0.01976285],
#          [0.00790514]],
#
#         ...,
#
#         [[0.01581028],
#          [0.        ],
#          [0.03162055],
#          ...,
#          [0.09881423],
#          [0.06324111],
#          [0.03557312]],
#
#         [[0.00395257],
#          [0.00395257],
#          [0.00790514],
#          ...,
#          [0.09486166],
#          [0.06324111],
#          [0.03952569]],
#
#         [[0.02371541],
#          [0.01976285],
#          [0.01581028],
#          ...,
#          [0.04743083],
#          [0.07905138],
#          [0.03952569]]],
#
#
#        ...,
#
#
#        [[[0.03162055],
#          [0.00395257],
#          [0.01976285],
#          ...,
#          [0.04743083],
#          [0.04743083],
#          [0.03952569]],
#
#         [[0.02371541],
#          [0.02371541],
#          [0.01976285],
#          ...,
#          [0.05533597],
#          [0.02766798],
#          [0.02766798]],
#
#         [[0.02371541],
#          [0.02371541],
#          [0.03162055],
#          ...,
#          [0.06324111],
#          [0.03557312],
#          [0.03952569]],
#
#         ...,
#
#         [[0.02766798],
#          [0.03162055],
#          [0.03557312],
#          ...,
#          [0.09881423],
#          [0.04347826],
#          [0.06324111]],
#
#         [[0.02766798],
#          [0.02766798],
#          [0.03557312],
#          ...,
#          [0.1027668 ],
#          [0.07905138],
#          [0.05533597]],
#
#         [[0.00395257],
#          [0.00790514],
#          [0.01976285],
#          ...,
#          [0.04743083],
#          [0.04347826],
#          [0.07905138]]],
#
#
#        [[[0.02362205],
#          [0.03149606],
#          [0.02755906],
#          ...,
#          [0.05905512],
#          [0.05905512],
#          [0.03543307]],
#
#         [[0.00787402],
#          [0.01181102],
#          [0.02755906],
#          ...,
#          [0.0511811 ],
#          [0.04330709],
#          [0.02755906]],
#
#         [[0.00787402],
#          [0.03149606],
#          [0.02362205],
#          ...,
#          [0.04330709],
#          [0.0511811 ],
#          [0.04330709]],
#
#         ...,
#
#         [[0.02362205],
#          [0.03937008],
#          [0.0511811 ],
#          ...,
#          [0.10236221],
#          [0.06692913],
#          [0.07086615]],
#
#         [[0.03937008],
#          [0.03149606],
#          [0.03149606],
#          ...,
#          [0.09842519],
#          [0.11811024],
#          [0.07874016]],
#
#         [[0.01968504],
#          [0.01968504],
#          [0.03149606],
#          ...,
#          [0.05905512],
#          [0.04724409],
#          [0.06692913]]],
#
#
#        [[[0.04724409],
#          [0.02755906],
#          [0.01181102],
#          ...,
#          [0.05905512],
#          [0.04724409],
#          [0.03937008]],
#
#         [[0.00393701],
#          [0.03149606],
#          [0.00393701],
#          ...,
#          [0.03149606],
#          [0.04724409],
#          [0.03937008]],
#
#         [[0.01968504],
#          [0.02362205],
#          [0.03149606],
#          ...,
#          [0.02362205],
#          [0.04724409],
#          [0.03937008]],
#
#         ...,
#
#         [[0.03149606],
#          [0.0511811 ],
#          [0.01968504],
#          ...,
#          [0.10236221],
#          [0.07086615],
#          [0.08661418]],
#
#         [[0.03937008],
#          [0.01181102],
#          [0.01968504],
#          ...,
#          [0.08267716],
#          [0.11417323],
#          [0.06692913]],
#
#         [[0.00787402],
#          [0.02755906],
#          [0.03149606],
#          ...,
#          [0.05905512],
#          [0.07086615],
#          [0.06692913]]]]), 'valid': array([[[[0.03543307],
#          [0.01181102],
#          [0.00787402],
#          ...,
#          [0.03937008],
#          [0.03543307],
#          [0.02362205]],
#
#         [[0.00787402],
#          [0.02362205],
#          [0.01181102],
#          ...,
#          [0.03937008],
#          [0.03543307],
#          [0.02362205]],
#
#         [[0.01968504],
#          [0.01181102],
#          [0.01968504],
#          ...,
#          [0.03149606],
#          [0.03543307],
#          [0.03149606]],
#
#         ...,
#
#         [[0.03149606],
#          [0.01968504],
#          [0.02755906],
#          ...,
#          [0.06299213],
#          [0.0511811 ],
#          [0.05905512]],
#
#         [[0.02362205],
#          [0.01181102],
#          [0.00787402],
#          ...,
#          [0.08661418],
#          [0.06692913],
#          [0.04330709]],
#
#         [[0.02362205],
#          [0.02755906],
#          [0.02362205],
#          ...,
#          [0.04724409],
#          [0.07086615],
#          [0.04330709]]],
#
#
#        [[[0.02362205],
#          [0.01968504],
#          [0.00787402],
#          ...,
#          [0.02755906],
#          [0.03149606],
#          [0.02755906]],
#
#         [[0.00787402],
#          [0.01181102],
#          [0.02362205],
#          ...,
#          [0.03149606],
#          [0.03543307],
#          [0.02755906]],
#
#         [[0.02362205],
#          [0.00393701],
#          [0.01968504],
#          ...,
#          [0.02755906],
#          [0.02362205],
#          [0.02362205]],
#
#         ...,
#
#         [[0.04330709],
#          [0.01968504],
#          [0.01181102],
#          ...,
#          [0.06692913],
#          [0.06692913],
#          [0.06299213]],
#
#         [[0.03149606],
#          [0.00787402],
#          [0.00393701],
#          ...,
#          [0.07874016],
#          [0.05905512],
#          [0.04724409]],
#
#         [[0.03149606],
#          [0.03149606],
#          [0.00787402],
#          ...,
#          [0.04330709],
#          [0.07086615],
#          [0.04724409]]],
#
#
#        [[[0.03543307],
#          [0.01181102],
#          [0.00787402],
#          ...,
#          [0.01968504],
#          [0.02362205],
#          [0.02755906]],
#
#         [[0.00393701],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.02362205],
#          [0.02755906],
#          [0.02755906]],
#
#         [[0.01968504],
#          [0.01181102],
#          [0.03149606],
#          ...,
#          [0.03149606],
#          [0.03149606],
#          [0.02755906]],
#
#         ...,
#
#         [[0.03937008],
#          [0.00787402],
#          [0.02362205],
#          ...,
#          [0.07086615],
#          [0.05905512],
#          [0.0511811 ]],
#
#         [[0.02362205],
#          [0.00787402],
#          [0.00787402],
#          ...,
#          [0.08267716],
#          [0.06299213],
#          [0.04330709]],
#
#         [[0.02362205],
#          [0.00787402],
#          [0.00393701],
#          ...,
#          [0.04330709],
#          [0.06692913],
#          [0.0511811 ]]],
#
#
#        ...,
#
#
#        [[[0.03149606],
#          [0.00787402],
#          [0.03543307],
#          ...,
#          [0.05905512],
#          [0.0511811 ],
#          [0.03937008]],
#
#         [[0.04724409],
#          [0.02362205],
#          [0.02755906],
#          ...,
#          [0.04330709],
#          [0.03149606],
#          [0.01968504]],
#
#         [[0.03937008],
#          [0.03149606],
#          [0.03543307],
#          ...,
#          [0.06692913],
#          [0.06299213],
#          [0.02755906]],
#
#         ...,
#
#         [[0.03543307],
#          [0.03543307],
#          [0.02755906],
#          ...,
#          [0.07874016],
#          [0.05905512],
#          [0.07086615]],
#
#         [[0.02362205],
#          [0.03543307],
#          [0.02362205],
#          ...,
#          [0.03149606],
#          [0.10236221],
#          [0.04724409]],
#
#         [[0.03543307],
#          [0.03149606],
#          [0.02755906],
#          ...,
#          [0.06299213],
#          [0.08267716],
#          [0.06299213]]],
#
#
#        [[[0.00790514],
#          [0.03162055],
#          [0.01976285],
#          ...,
#          [0.05928854],
#          [0.04347826],
#          [0.02371541]],
#
#         [[0.03557312],
#          [0.01976285],
#          [0.03162055],
#          ...,
#          [0.04743083],
#          [0.01581028],
#          [0.01581028]],
#
#         [[0.01976285],
#          [0.00790514],
#          [0.03557312],
#          ...,
#          [0.03952569],
#          [0.04347826],
#          [0.02371541]],
#
#         ...,
#
#         [[0.02371541],
#          [0.03162055],
#          [0.02371541],
#          ...,
#          [0.07509881],
#          [0.04743083],
#          [0.04347826]],
#
#         [[0.02766798],
#          [0.02766798],
#          [0.01581028],
#          ...,
#          [0.03557312],
#          [0.10671937],
#          [0.04347826]],
#
#         [[0.02766798],
#          [0.00790514],
#          [0.03162055],
#          ...,
#          [0.05928854],
#          [0.06719368],
#          [0.07114624]]],
#
#
#        [[[0.02362205],
#          [0.02362205],
#          [0.03543307],
#          ...,
#          [0.04724409],
#          [0.03937008],
#          [0.03543307]],
#
#         [[0.01181102],
#          [0.04330709],
#          [0.03149606],
#          ...,
#          [0.0511811 ],
#          [0.01968504],
#          [0.02755906]],
#
#         [[0.00787402],
#          [0.01968504],
#          [0.02362205],
#          ...,
#          [0.0511811 ],
#          [0.04724409],
#          [0.01968504]],
#
#         ...,
#
#         [[0.01968504],
#          [0.03543307],
#          [0.03543307],
#          ...,
#          [0.11023622],
#          [0.04330709],
#          [0.06692913]],
#
#         [[0.01968504],
#          [0.03149606],
#          [0.02362205],
#          ...,
#          [0.07480315],
#          [0.11023622],
#          [0.0511811 ]],
#
#         [[0.02362205],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.0511811 ],
#          [0.07086615],
#          [0.06692913]]]])}
# 44585
# 68
# 68
# 1
# 2281
# 68
# 68
# 1
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# starting training M2 2024-10-30_08-49-22
# Epoch 1/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - loss: 0.0108 - val_loss: 0.0035
# Epoch 2/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 3/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 4/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 5/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 6/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 7/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 8/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 9/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 10/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 11/100
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0021 - val_loss: 0.0033
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step
# 0.002644635371273108
# valid files ['usctimit_mri_m3_081_085.avi', 'usctimit_mri_m3_171_175.avi', 'usctimit_mri_m3_251_255.avi', 'usctimit_mri_m3_406_410.avi']
# test files ['usctimit_mri_m3_441_445.avi', 'usctimit_mri_m3_146_150.avi', 'usctimit_mri_m3_261_265.avi', 'usctimit_mri_m3_121_125.avi', 'usctimit_mri_m3_316_320.avi', 'usctimit_mri_m3_416_420.avi', 'usctimit_mri_m3_101_105.avi', 'usctimit_mri_m3_061_065.avi', 'usctimit_mri_m3_091_095.avi', 'usctimit_mri_m3_401_405.avi']
# starting train usctimit_mri_m3_166_170.avi
# minmax: 0.0 1.0
# n_frames_all:  443 mgc_size:  443
# starting train usctimit_mri_m3_306_310.avi
# minmax: 0.0 1.0
# n_frames_all:  985 mgc_size:  985
# starting train usctimit_mri_m3_051_055.avi
# minmax: 0.0 1.0
# n_frames_all:  1460 mgc_size:  1460
# starting train usctimit_mri_m3_056_060.avi
# minmax: 0.0 1.0
# n_frames_all:  1944 mgc_size:  1944
# starting train usctimit_mri_m3_276_280.avi
# minmax: 0.0 1.0
# n_frames_all:  2438 mgc_size:  2438
# starting train usctimit_mri_m3_241_245.avi
# minmax: 0.0 1.0
# n_frames_all:  2888 mgc_size:  2888
# starting train usctimit_mri_m3_021_025.avi
# minmax: 0.0 1.0
# n_frames_all:  3308 mgc_size:  3308
# starting train usctimit_mri_m3_221_225.avi
# minmax: 0.0 1.0
# n_frames_all:  3826 mgc_size:  3826
# starting train usctimit_mri_m3_141_145.avi
# minmax: 0.0 1.0
# n_frames_all:  4401 mgc_size:  4401
# starting train usctimit_mri_m3_366_370.avi
# minmax: 0.0 1.0
# n_frames_all:  4965 mgc_size:  4965
# starting train usctimit_mri_m3_346_350.avi
# minmax: 0.0 1.0
# n_frames_all:  5456 mgc_size:  5456
# starting train usctimit_mri_m3_396_400.avi
# minmax: 0.0 1.0
# n_frames_all:  6017 mgc_size:  6017
# starting train usctimit_mri_m3_031_035.avi
# minmax: 0.0 1.0
# n_frames_all:  6532 mgc_size:  6532
# starting train usctimit_mri_m3_456_460.avi
# minmax: 0.0 1.0
# n_frames_all:  7119 mgc_size:  7119
# starting train usctimit_mri_m3_281_285.avi
# minmax: 0.0 1.0
# n_frames_all:  7769 mgc_size:  7769
# starting train usctimit_mri_m3_011_015.avi
# minmax: 0.0 1.0
# n_frames_all:  8218 mgc_size:  8218
# starting train usctimit_mri_m3_386_390.avi
# minmax: 0.0 1.0
# n_frames_all:  8817 mgc_size:  8817
# starting train usctimit_mri_m3_296_300.avi
# minmax: 0.0 1.0
# n_frames_all:  9467 mgc_size:  9467
# starting train usctimit_mri_m3_206_210.avi
# minmax: 0.0 1.0
# n_frames_all:  9942 mgc_size:  9942
# starting train usctimit_mri_m3_286_290.avi
# minmax: 0.0 1.0
# n_frames_all:  10478 mgc_size:  10478
# starting train usctimit_mri_m3_066_070.avi
# minmax: 0.0 1.0
# n_frames_all:  10986 mgc_size:  10986
# starting train usctimit_mri_m3_421_425.avi
# minmax: 0.0 1.0
# n_frames_all:  11480 mgc_size:  11480
# starting train usctimit_mri_m3_361_365.avi
# minmax: 0.0 1.0
# n_frames_all:  11991 mgc_size:  11991
# starting train usctimit_mri_m3_326_330.avi
# minmax: 0.0 1.0
# n_frames_all:  12626 mgc_size:  12626
# starting train usctimit_mri_m3_426_430.avi
# minmax: 0.0 1.0
# n_frames_all:  13202 mgc_size:  13202
# starting train usctimit_mri_m3_001_005.avi
# minmax: 0.0 1.0
# n_frames_all:  13620 mgc_size:  13620
# starting train usctimit_mri_m3_436_440.avi
# minmax: 0.0 1.0
# n_frames_all:  14129 mgc_size:  14129
# starting train usctimit_mri_m3_236_240.avi
# minmax: 0.0 1.0
# n_frames_all:  14641 mgc_size:  14641
# starting train usctimit_mri_m3_291_295.avi
# minmax: 0.0 1.0
# n_frames_all:  15181 mgc_size:  15181
# starting train usctimit_mri_m3_226_230.avi
# minmax: 0.0 1.0
# n_frames_all:  15657 mgc_size:  15657
# starting train usctimit_mri_m3_431_435.avi
# minmax: 0.0 1.0
# n_frames_all:  16068 mgc_size:  16068
# starting train usctimit_mri_m3_411_415.avi
# minmax: 0.0 1.0
# n_frames_all:  16576 mgc_size:  16576
# starting train usctimit_mri_m3_181_185.avi
# minmax: 0.0 1.0
# n_frames_all:  17104 mgc_size:  17104
# starting train usctimit_mri_m3_116_120.avi
# minmax: 0.0 1.0
# n_frames_all:  17606 mgc_size:  17606
# starting train usctimit_mri_m3_136_140.avi
# minmax: 0.0 1.0
# n_frames_all:  18147 mgc_size:  18147
# starting train usctimit_mri_m3_006_010.avi
# minmax: 0.0 1.0
# n_frames_all:  18577 mgc_size:  18577
# starting train usctimit_mri_m3_106_110.avi
# minmax: 0.0 1.0
# n_frames_all:  19087 mgc_size:  19087
# starting train usctimit_mri_m3_301_305.avi
# minmax: 0.0 1.0
# n_frames_all:  19710 mgc_size:  19710
# starting train usctimit_mri_m3_311_315.avi
# minmax: 0.0 1.0
# n_frames_all:  20347 mgc_size:  20347
# starting train usctimit_mri_m3_376_380.avi
# minmax: 0.0 1.0
# n_frames_all:  20860 mgc_size:  20860
# starting train usctimit_mri_m3_216_220.avi
# minmax: 0.0 1.0
# n_frames_all:  21380 mgc_size:  21380
# starting train usctimit_mri_m3_046_050.avi
# minmax: 0.0 1.0
# n_frames_all:  21923 mgc_size:  21923
# starting train usctimit_mri_m3_446_450.avi
# minmax: 0.0 1.0
# n_frames_all:  22416 mgc_size:  22416
# starting train usctimit_mri_m3_381_385.avi
# minmax: 0.0 1.0
# n_frames_all:  22932 mgc_size:  22932
# starting train usctimit_mri_m3_151_155.avi
# minmax: 0.0 1.0
# n_frames_all:  23532 mgc_size:  23532
# starting train usctimit_mri_m3_271_275.avi
# minmax: 0.0 1.0
# n_frames_all:  24010 mgc_size:  24010
# starting train usctimit_mri_m3_391_395.avi
# minmax: 0.0 1.0
# n_frames_all:  24585 mgc_size:  24585
# starting train usctimit_mri_m3_026_030.avi
# minmax: 0.0 1.0
# n_frames_all:  25067 mgc_size:  25067
# starting train usctimit_mri_m3_341_345.avi
# minmax: 0.0 1.0
# n_frames_all:  25569 mgc_size:  25569
# starting train usctimit_mri_m3_196_200.avi
# minmax: 0.0 1.0
# n_frames_all:  26092 mgc_size:  26092
# starting train usctimit_mri_m3_041_045.avi
# minmax: 0.0 1.0
# n_frames_all:  26634 mgc_size:  26634
# starting train usctimit_mri_m3_076_080.avi
# minmax: 0.0 1.0
# n_frames_all:  27099 mgc_size:  27099
# starting train usctimit_mri_m3_211_215.avi
# minmax: 0.0 1.0
# n_frames_all:  27564 mgc_size:  27564
# starting train usctimit_mri_m3_131_135.avi
# minmax: 0.0 1.0
# n_frames_all:  28101 mgc_size:  28101
# starting train usctimit_mri_m3_096_100.avi
# minmax: 0.0 1.0
# n_frames_all:  28583 mgc_size:  28583
# starting train usctimit_mri_m3_126_130.avi
# minmax: 0.0 1.0
# n_frames_all:  29111 mgc_size:  29111
# starting train usctimit_mri_m3_371_375.avi
# minmax: 0.0 1.0
# n_frames_all:  29683 mgc_size:  29683
# starting train usctimit_mri_m3_036_040.avi
# minmax: 0.0 1.0
# n_frames_all:  30218 mgc_size:  30218
# starting train usctimit_mri_m3_356_360.avi
# minmax: 0.0 1.0
# n_frames_all:  30720 mgc_size:  30720
# starting train usctimit_mri_m3_086_090.avi
# minmax: 0.0 1.0
# n_frames_all:  31151 mgc_size:  31151
# starting train usctimit_mri_m3_256_260.avi
# minmax: 0.0 1.0
# n_frames_all:  31727 mgc_size:  31727
# starting train usctimit_mri_m3_201_205.avi
# minmax: 0.0 1.0
# n_frames_all:  32153 mgc_size:  32153
# starting train usctimit_mri_m3_321_325.avi
# minmax: 0.0 1.0
# n_frames_all:  32674 mgc_size:  32674
# starting train usctimit_mri_m3_161_165.avi
# minmax: 0.0 1.0
# n_frames_all:  33215 mgc_size:  33215
# starting train usctimit_mri_m3_451_455.avi
# minmax: 0.0 1.0
# n_frames_all:  33815 mgc_size:  33815
# starting train usctimit_mri_m3_246_250.avi
# minmax: 0.0 1.0
# n_frames_all:  34297 mgc_size:  34297
# starting train usctimit_mri_m3_156_160.avi
# minmax: 0.0 1.0
# n_frames_all:  34865 mgc_size:  34865
# starting train usctimit_mri_m3_016_020.avi
# minmax: 0.0 1.0
# n_frames_all:  35285 mgc_size:  35285
# starting train usctimit_mri_m3_071_075.avi
# minmax: 0.0 1.0
# n_frames_all:  35790 mgc_size:  35790
# starting train usctimit_mri_m3_176_180.avi
# minmax: 0.0 1.0
# n_frames_all:  36191 mgc_size:  36191
# starting train usctimit_mri_m3_351_355.avi
# minmax: 0.0 1.0
# n_frames_all:  36740 mgc_size:  36740
# starting train usctimit_mri_m3_111_115.avi
# minmax: 0.0 1.0
# n_frames_all:  37194 mgc_size:  37194
# starting train usctimit_mri_m3_186_190.avi
# minmax: 0.0 1.0
# n_frames_all:  37729 mgc_size:  37729
# starting train usctimit_mri_m3_231_235.avi
# minmax: 0.0 1.0
# n_frames_all:  38209 mgc_size:  38209
# starting train usctimit_mri_m3_191_195.avi
# minmax: 0.0 1.0
# n_frames_all:  38736 mgc_size:  38736
# starting train usctimit_mri_m3_266_270.avi
# minmax: 0.0 1.0
# n_frames_all:  39271 mgc_size:  39271
# starting train usctimit_mri_m3_336_340.avi
# minmax: 0.0 1.0
# n_frames_all:  39797 mgc_size:  39797
# starting valid usctimit_mri_m3_081_085.avi
# minmax: 0.0 1.0
# n_frames_all:  468 mgc_size:  468
# starting valid usctimit_mri_m3_171_175.avi
# minmax: 0.0 1.0
# n_frames_all:  938 mgc_size:  938
# starting valid usctimit_mri_m3_251_255.avi
# minmax: 0.0 1.0
# n_frames_all:  1513 mgc_size:  1513
# starting valid usctimit_mri_m3_406_410.avi
# minmax: 0.0 1.0
# n_frames_all:  1998 mgc_size:  1998
# {'train': array([[[[0.01181102],
#          [0.00787402],
#          [0.        ],
#          ...,
#          [0.01968504],
#          [0.01968504],
#          [0.01181102]],
#
#         [[0.01968504],
#          [0.00393701],
#          [0.00787402],
#          ...,
#          [0.02755906],
#          [0.02362205],
#          [0.01181102]],
#
#         [[0.00787402],
#          [0.00787402],
#          [0.01968504],
#          ...,
#          [0.02755906],
#          [0.00787402],
#          [0.01968504]],
#
#         ...,
#
#         [[0.03149606],
#          [0.01181102],
#          [0.03543307],
#          ...,
#          [0.06692913],
#          [0.04330709],
#          [0.03543307]],
#
#         [[0.01968504],
#          [0.00787402],
#          [0.03149606],
#          ...,
#          [0.05905512],
#          [0.04724409],
#          [0.03937008]],
#
#         [[0.02755906],
#          [0.03543307],
#          [0.02755906],
#          ...,
#          [0.07480315],
#          [0.07480315],
#          [0.04724409]]],
#
#
#        [[[0.        ],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.02362205],
#          [0.00787402],
#          [0.01181102]],
#
#         [[0.01968504],
#          [0.02362205],
#          [0.02362205],
#          ...,
#          [0.01968504],
#          [0.01181102],
#          [0.01181102]],
#
#         [[0.01181102],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.02362205],
#          [0.01968504],
#          [0.01181102]],
#
#         ...,
#
#         [[0.04330709],
#          [0.02362205],
#          [0.02362205],
#          ...,
#          [0.06299213],
#          [0.04330709],
#          [0.03937008]],
#
#         [[0.02362205],
#          [0.00393701],
#          [0.02362205],
#          ...,
#          [0.04724409],
#          [0.03937008],
#          [0.03543307]],
#
#         [[0.03149606],
#          [0.03937008],
#          [0.01968504],
#          ...,
#          [0.05905512],
#          [0.07086615],
#          [0.04330709]]],
#
#
#        [[[0.00393701],
#          [0.00787402],
#          [0.00787402],
#          ...,
#          [0.02362205],
#          [0.01181102],
#          [0.00787402]],
#
#         [[0.01181102],
#          [0.00787402],
#          [0.00787402],
#          ...,
#          [0.01968504],
#          [0.01968504],
#          [0.02362205]],
#
#         [[0.01181102],
#          [0.00787402],
#          [0.01968504],
#          ...,
#          [0.01181102],
#          [0.01181102],
#          [0.00787402]],
#
#         ...,
#
#         [[0.04724409],
#          [0.02362205],
#          [0.02755906],
#          ...,
#          [0.06299213],
#          [0.04330709],
#          [0.04724409]],
#
#         [[0.01968504],
#          [0.00393701],
#          [0.02362205],
#          ...,
#          [0.06299213],
#          [0.03543307],
#          [0.04330709]],
#
#         [[0.03149606],
#          [0.03937008],
#          [0.02362205],
#          ...,
#          [0.05905512],
#          [0.07480315],
#          [0.04724409]]],
#
#
#        ...,
#
#
#        [[[0.01968504],
#          [0.01968504],
#          [0.01181102],
#          ...,
#          [0.01968504],
#          [0.01181102],
#          [0.01181102]],
#
#         [[0.02755906],
#          [0.03149606],
#          [0.02362205],
#          ...,
#          [0.02755906],
#          [0.01181102],
#          [0.01968504]],
#
#         [[0.02362205],
#          [0.03149606],
#          [0.02755906],
#          ...,
#          [0.01968504],
#          [0.03543307],
#          [0.03149606]],
#
#         ...,
#
#         [[0.03149606],
#          [0.01181102],
#          [0.02362205],
#          ...,
#          [0.04724409],
#          [0.06692913],
#          [0.07086615]],
#
#         [[0.02362205],
#          [0.00787402],
#          [0.02362205],
#          ...,
#          [0.02755906],
#          [0.05905512],
#          [0.06692913]],
#
#         [[0.01968504],
#          [0.03149606],
#          [0.03149606],
#          ...,
#          [0.06299213],
#          [0.07874016],
#          [0.06692913]]],
#
#
#        [[[0.01968504],
#          [0.01968504],
#          [0.02362205],
#          ...,
#          [0.02755906],
#          [0.02362205],
#          [0.02362205]],
#
#         [[0.02755906],
#          [0.03937008],
#          [0.03149606],
#          ...,
#          [0.03937008],
#          [0.01968504],
#          [0.00787402]],
#
#         [[0.02755906],
#          [0.03543307],
#          [0.01181102],
#          ...,
#          [0.02362205],
#          [0.00787402],
#          [0.02362205]],
#
#         ...,
#
#         [[0.03543307],
#          [0.01968504],
#          [0.02755906],
#          ...,
#          [0.0511811 ],
#          [0.06692913],
#          [0.06299213]],
#
#         [[0.01968504],
#          [0.01181102],
#          [0.01968504],
#          ...,
#          [0.04724409],
#          [0.07086615],
#          [0.06299213]],
#
#         [[0.01968504],
#          [0.03937008],
#          [0.04724409],
#          ...,
#          [0.0511811 ],
#          [0.07874016],
#          [0.06299213]]],
#
#
#        [[[0.01968504],
#          [0.02362205],
#          [0.01968504],
#          ...,
#          [0.02755906],
#          [0.03149606],
#          [0.03149606]],
#
#         [[0.03149606],
#          [0.01968504],
#          [0.01968504],
#          ...,
#          [0.04330709],
#          [0.02362205],
#          [0.01968504]],
#
#         [[0.03149606],
#          [0.01968504],
#          [0.02755906],
#          ...,
#          [0.02755906],
#          [0.01181102],
#          [0.01968504]],
#
#         ...,
#
#         [[0.03149606],
#          [0.02362205],
#          [0.02755906],
#          ...,
#          [0.06299213],
#          [0.06299213],
#          [0.04724409]],
#
#         [[0.00787402],
#          [0.01181102],
#          [0.01968504],
#          ...,
#          [0.07480315],
#          [0.07480315],
#          [0.07086615]],
#
#         [[0.02362205],
#          [0.05905512],
#          [0.04724409],
#          ...,
#          [0.04330709],
#          [0.07874016],
#          [0.06692913]]]]), 'valid': array([[[[0.00393701],
#          [0.00787402],
#          [0.01968504],
#          ...,
#          [0.00393701],
#          [0.01181102],
#          [0.01968504]],
#
#         [[0.00787402],
#          [0.01968504],
#          [0.03149606],
#          ...,
#          [0.01181102],
#          [0.00787402],
#          [0.00393701]],
#
#         [[0.01968504],
#          [0.02362205],
#          [0.02362205],
#          ...,
#          [0.01968504],
#          [0.01968504],
#          [0.01968504]],
#
#         ...,
#
#         [[0.03937008],
#          [0.02755906],
#          [0.03937008],
#          ...,
#          [0.06692913],
#          [0.03937008],
#          [0.04724409]],
#
#         [[0.01968504],
#          [0.00787402],
#          [0.02755906],
#          ...,
#          [0.06692913],
#          [0.06299213],
#          [0.06299213]],
#
#         [[0.02362205],
#          [0.03149606],
#          [0.02362205],
#          ...,
#          [0.07086615],
#          [0.07874016],
#          [0.04724409]]],
#
#
#        [[[0.00787402],
#          [0.00393701],
#          [0.02362205],
#          ...,
#          [0.02362205],
#          [0.01968504],
#          [0.02755906]],
#
#         [[0.02362205],
#          [0.01181102],
#          [0.01968504],
#          ...,
#          [0.01181102],
#          [0.01181102],
#          [0.00787402]],
#
#         [[0.00787402],
#          [0.02362205],
#          [0.03149606],
#          ...,
#          [0.01968504],
#          [0.01181102],
#          [0.01181102]],
#
#         ...,
#
#         [[0.03543307],
#          [0.00787402],
#          [0.03149606],
#          ...,
#          [0.07086615],
#          [0.03937008],
#          [0.0511811 ]],
#
#         [[0.01181102],
#          [0.00787402],
#          [0.03149606],
#          ...,
#          [0.06692913],
#          [0.06692913],
#          [0.06299213]],
#
#         [[0.02755906],
#          [0.03543307],
#          [0.01968504],
#          ...,
#          [0.06299213],
#          [0.07480315],
#          [0.04724409]]],
#
#
#        [[[0.01976285],
#          [0.01976285],
#          [0.02371541],
#          ...,
#          [0.01976285],
#          [0.01581028],
#          [0.01581028]],
#
#         [[0.02371541],
#          [0.        ],
#          [0.02371541],
#          ...,
#          [0.01976285],
#          [0.00790514],
#          [0.00395257]],
#
#         [[0.01976285],
#          [0.02371541],
#          [0.02766798],
#          ...,
#          [0.01976285],
#          [0.02371541],
#          [0.01976285]],
#
#         ...,
#
#         [[0.01976285],
#          [0.01976285],
#          [0.01976285],
#          ...,
#          [0.05928854],
#          [0.04347826],
#          [0.04347826]],
#
#         [[0.01581028],
#          [0.01581028],
#          [0.02371541],
#          ...,
#          [0.05533597],
#          [0.05533597],
#          [0.04347826]],
#
#         [[0.02371541],
#          [0.02766798],
#          [0.02766798],
#          ...,
#          [0.06324111],
#          [0.07905138],
#          [0.05533597]]],
#
#
#        ...,
#
#
#        [[[0.00787402],
#          [0.02362205],
#          [0.00393701],
#          ...,
#          [0.03543307],
#          [0.03543307],
#          [0.02755906]],
#
#         [[0.02755906],
#          [0.00393701],
#          [0.03543307],
#          ...,
#          [0.04330709],
#          [0.03149606],
#          [0.00787402]],
#
#         [[0.01968504],
#          [0.03937008],
#          [0.02362205],
#          ...,
#          [0.01181102],
#          [0.02362205],
#          [0.02362205]],
#
#         ...,
#
#         [[0.02362205],
#          [0.02755906],
#          [0.03543307],
#          ...,
#          [0.0511811 ],
#          [0.07086615],
#          [0.0511811 ]],
#
#         [[0.03543307],
#          [0.02755906],
#          [0.00787402],
#          ...,
#          [0.04724409],
#          [0.06299213],
#          [0.06299213]],
#
#         [[0.08661418],
#          [0.02362205],
#          [0.04330709],
#          ...,
#          [0.08267716],
#          [0.06692913],
#          [0.0511811 ]]],
#
#
#        [[[0.03149606],
#          [0.04330709],
#          [0.02362205],
#          ...,
#          [0.02362205],
#          [0.02362205],
#          [0.03937008]],
#
#         [[0.01181102],
#          [0.02755906],
#          [0.04724409],
#          ...,
#          [0.02755906],
#          [0.03149606],
#          [0.00787402]],
#
#         [[0.02362205],
#          [0.01181102],
#          [0.03149606],
#          ...,
#          [0.02362205],
#          [0.03543307],
#          [0.00393701]],
#
#         ...,
#
#         [[0.03937008],
#          [0.04330709],
#          [0.02755906],
#          ...,
#          [0.0511811 ],
#          [0.07086615],
#          [0.06299213]],
#
#         [[0.03937008],
#          [0.04330709],
#          [0.02362205],
#          ...,
#          [0.0511811 ],
#          [0.05905512],
#          [0.04330709]],
#
#         [[0.0511811 ],
#          [0.02362205],
#          [0.06692913],
#          ...,
#          [0.08661418],
#          [0.06299213],
#          [0.05905512]]],
#
#
#        [[[0.02362205],
#          [0.02362205],
#          [0.02362205],
#          ...,
#          [0.03937008],
#          [0.00393701],
#          [0.01968504]],
#
#         [[0.00393701],
#          [0.01968504],
#          [0.0511811 ],
#          ...,
#          [0.03149606],
#          [0.03543307],
#          [0.00393701]],
#
#         [[0.00787402],
#          [0.03149606],
#          [0.02362205],
#          ...,
#          [0.03543307],
#          [0.03937008],
#          [0.02362205]],
#
#         ...,
#
#         [[0.04724409],
#          [0.04724409],
#          [0.02362205],
#          ...,
#          [0.06299213],
#          [0.0511811 ],
#          [0.06299213]],
#
#         [[0.02362205],
#          [0.03937008],
#          [0.03149606],
#          ...,
#          [0.06299213],
#          [0.05905512],
#          [0.04330709]],
#
#         [[0.0511811 ],
#          [0.0511811 ],
#          [0.06299213],
#          ...,
#          [0.09842519],
#          [0.07480315],
#          [0.0511811 ]]]])}
# 39797
# 68
# 68
# 1
# 1998
# 68
# 68
# 1
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# starting training M3 2024-10-30_08-53-07
# Epoch 1/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - loss: 0.0096 - val_loss: 0.0031
# Epoch 2/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 3/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 4/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 5/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 6/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 7/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 8/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 9/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 10/100
# 311/311 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0024 - val_loss: 0.0029
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_3 (TimeDistributed) │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_3 (TimeDistributed) │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 10, 575)             │         331,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# ...
# minmax: 0.0 1.0
# n_frames_all:  1695 mgc_size:  1695
# starting valid usctimit_mri_f2_401_405.avi
# minmax: 0.0 1.0
# n_frames_all:  2296 mgc_size:  2296
# {'train': array([[[[0.03149606],
#          [0.03543307],
#          [0.04330709],
#          ...,
#          [0.01181102],
#          [0.00393701],
#          [0.01968504]],
#
#         [[0.03543307],
#          [0.03149606],
#          [0.03937008],
#          ...,
#          [0.01968504],
#          [0.01181102],
#          [0.02362205]],
#
#         [[0.04330709],
#          [0.03149606],
#          [0.0511811 ],
#          ...,
#          [0.01181102],
#          [0.01968504],
#          [0.02362205]],
#
#         ...,
#
#         [[0.03937008],
#          [0.04330709],
#          [0.03543307],
#          ...,
#          [0.03543307],
#          [0.02362205],
#          [0.0511811 ]],
#
#         [[0.02362205],
#          [0.04330709],
#          [0.04724409],
#          ...,
#          [0.01968504],
#          [0.02362205],
#          [0.05905512]],
#
#         [[0.01968504],
#          [0.02755906],
#          [0.01968504],
#          ...,
#          [0.03149606],
#          [0.03937008],
#          [0.03543307]]],
#
#
#        [[[0.03149606],
#          [0.03543307],
#          [0.04330709],
#          ...,
#          [0.01181102],
#          [0.01968504],
#          [0.00393701]],
#
#         [[0.03149606],
#          [0.02362205],
#          [0.02755906],
#          ...,
#          [0.01968504],
#          [0.03149606],
#          [0.02362205]],
#
#         [[0.03543307],
#          [0.03937008],
#          [0.0511811 ],
#          ...,
#          [0.01181102],
#          [0.01968504],
#          [0.02755906]],
#
#         ...,
#
#         [[0.03937008],
#          [0.04330709],
#          [0.03543307],
#          ...,
#          [0.03937008],
#          [0.02755906],
#          [0.03543307]],
#
#         [[0.01181102],
#          [0.01968504],
#          [0.04330709],
#          ...,
#          [0.02755906],
#          [0.02362205],
#          [0.03149606]],
#
#         [[0.02755906],
#          [0.01181102],
#          [0.00787402],
#          ...,
#          [0.03937008],
#          [0.02362205],
#          [0.03937008]]],
#
#
#        [[[0.03937008],
#          [0.03543307],
#          [0.03543307],
#          ...,
#          [0.01968504],
#          [0.01181102],
#          [0.02362205]],
#
#         [[0.03149606],
#          [0.02755906],
#          [0.03937008],
#          ...,
#          [0.01968504],
#          [0.01968504],
#          [0.03149606]],
#
#         [[0.03543307],
#          [0.04724409],
#          [0.0511811 ],
#          ...,
#          [0.01181102],
#          [0.02755906],
#          [0.03149606]],
#
#         ...,
#
#         [[0.04330709],
#          [0.04330709],
#          [0.03149606],
#          ...,
#          [0.03937008],
#          [0.03149606],
#          [0.04330709]],
#
#         [[0.03543307],
#          [0.03937008],
#          [0.04330709],
#          ...,
#          [0.03149606],
#          [0.02362205],
#          [0.03543307]],
#
#         [[0.02755906],
#          [0.03149606],
#          [0.02755906],
#          ...,
#          [0.02755906],
#          [0.03149606],
#          [0.04330709]]],
#
#
#        ...,
#
#
#        [[[0.06692913],
#          [0.03937008],
#          [0.03937008],
#          ...,
#          [0.00787402],
#          [0.01968504],
#          [0.02755906]],
#
#         [[0.06299213],
#          [0.07874016],
#          [0.07086615],
#          ...,
#          [0.01968504],
#          [0.04330709],
#          [0.03543307]],
#
#         [[0.06692913],
#          [0.06692913],
#          [0.0511811 ],
#          ...,
#          [0.01181102],
#          [0.00787402],
#          [0.05905512]],
#
#         ...,
#
#         [[0.0511811 ],
#          [0.03937008],
#          [0.03543307],
#          ...,
#          [0.03543307],
#          [0.06692913],
#          [0.06299213]],
#
#         [[0.05905512],
#          [0.0511811 ],
#          [0.01181102],
#          ...,
#          [0.03543307],
#          [0.01968504],
#          [0.0511811 ]],
#
#         [[0.00393701],
#          [0.02755906],
#          [0.02755906],
#          ...,
#          [0.04330709],
#          [0.03937008],
#          [0.06692913]]],
#
#
#        [[[0.05533597],
#          [0.04743083],
#          [0.04347826],
#          ...,
#          [0.        ],
#          [0.01581028],
#          [0.03162055]],
#
#         [[0.03952569],
#          [0.06324111],
#          [0.06324111],
#          ...,
#          [0.02371541],
#          [0.02766798],
#          [0.03557312]],
#
#         [[0.07114624],
#          [0.04743083],
#          [0.05928854],
#          ...,
#          [0.02371541],
#          [0.02371541],
#          [0.03952569]],
#
#         ...,
#
#         [[0.03952569],
#          [0.02371541],
#          [0.02766798],
#          ...,
#          [0.03557312],
#          [0.03162055],
#          [0.04347826]],
#
#         [[0.03952569],
#          [0.04347826],
#          [0.02371541],
#          ...,
#          [0.06719368],
#          [0.02766798],
#          [0.05533597]],
#
#         [[0.01976285],
#          [0.04347826],
#          [0.03162055],
#          ...,
#          [0.02371541],
#          [0.05533597],
#          [0.06324111]]],
#
#
#        [[[0.05905512],
#          [0.06692913],
#          [0.0511811 ],
#          ...,
#          [0.01968504],
#          [0.01968504],
#          [0.01968504]],
#
#         [[0.03543307],
#          [0.06692913],
#          [0.06299213],
#          ...,
#          [0.02362205],
#          [0.02362205],
#          [0.03543307]],
#
#         [[0.07480315],
#          [0.07480315],
#          [0.04330709],
#          ...,
#          [0.02755906],
#          [0.02755906],
#          [0.01181102]],
#
#         ...,
#
#         [[0.06299213],
#          [0.03149606],
#          [0.01968504],
#          ...,
#          [0.0511811 ],
#          [0.04330709],
#          [0.02755906]],
#
#         [[0.04330709],
#          [0.05905512],
#          [0.04330709],
#          ...,
#          [0.03543307],
#          [0.03543307],
#          [0.06299213]],
#
#         [[0.03149606],
#          [0.05905512],
#          [0.04724409],
#          ...,
#          [0.04330709],
#          [0.06692913],
#          [0.06692913]]]]), 'valid': array([[[[0.02755906],
#          [0.03543307],
#          [0.03937008],
#          ...,
#          [0.03149606],
#          [0.02362205],
#          [0.02755906]],
#
#         [[0.02755906],
#          [0.03543307],
#          [0.0511811 ],
#          ...,
#          [0.03149606],
#          [0.03543307],
#          [0.03543307]],
#
#         [[0.04724409],
#          [0.04330709],
#          [0.05905512],
#          ...,
#          [0.03937008],
#          [0.03543307],
#          [0.03937008]],
#
#         ...,
#
#         [[0.02362205],
#          [0.03149606],
#          [0.04330709],
#          ...,
#          [0.02755906],
#          [0.01968504],
#          [0.03543307]],
#
#         [[0.01968504],
#          [0.01181102],
#          [0.03149606],
#          ...,
#          [0.04724409],
#          [0.04330709],
#          [0.03543307]],
#
#         [[0.03149606],
#          [0.02755906],
#          [0.02755906],
#          ...,
#          [0.04724409],
#          [0.0511811 ],
#          [0.03149606]]],
#
#
#        [[[0.02755906],
#          [0.03149606],
#          [0.03543307],
#          ...,
#          [0.02362205],
#          [0.00787402],
#          [0.01181102]],
#
#         [[0.02755906],
#          [0.03149606],
#          [0.0511811 ],
#          ...,
#          [0.01968504],
#          [0.02755906],
#          [0.02362205]],
#
#         [[0.04330709],
#          [0.04330709],
#          [0.04724409],
#          ...,
#          [0.02755906],
#          [0.03149606],
#          [0.03543307]],
#
#         ...,
#
#         [[0.03543307],
#          [0.03937008],
#          [0.05905512],
#          ...,
#          [0.01968504],
#          [0.02362205],
#          [0.04724409]],
#
#         [[0.03543307],
#          [0.01181102],
#          [0.02362205],
#          ...,
#          [0.03937008],
#          [0.03937008],
#          [0.03543307]],
#
#         [[0.02755906],
#          [0.03149606],
#          [0.01968504],
#          ...,
#          [0.04724409],
#          [0.05905512],
#          [0.03937008]]],
#
#
#        [[[0.03149606],
#          [0.03543307],
#          [0.03149606],
#          ...,
#          [0.02362205],
#          [0.03543307],
#          [0.01181102]],
#
#         [[0.03543307],
#          [0.03937008],
#          [0.04724409],
#          ...,
#          [0.00787402],
#          [0.02755906],
#          [0.03937008]],
#
#         [[0.03937008],
#          [0.0511811 ],
#          [0.04330709],
#          ...,
#          [0.03543307],
#          [0.03937008],
#          [0.03543307]],
#
#         ...,
#
#         [[0.03543307],
#          [0.03543307],
#          [0.05905512],
#          ...,
#          [0.02755906],
#          [0.02362205],
#          [0.04330709]],
#
#         [[0.03149606],
#          [0.01181102],
#          [0.01181102],
#          ...,
#          [0.03149606],
#          [0.03543307],
#          [0.03937008]],
#
#         [[0.01968504],
#          [0.02362205],
#          [0.02755906],
#          ...,
#          [0.04330709],
#          [0.04724409],
#          [0.04330709]]],
#
#
#        ...,
#
#
#        [[[0.07086615],
#          [0.0511811 ],
#          [0.0511811 ],
#          ...,
#          [0.00787402],
#          [0.01968504],
#          [0.02755906]],
#
#         [[0.06299213],
#          [0.03937008],
#          [0.04330709],
#          ...,
#          [0.01968504],
#          [0.00393701],
#          [0.01968504]],
#
#         [[0.03543307],
#          [0.04724409],
#          [0.0511811 ],
#          ...,
#          [0.03543307],
#          [0.01968504],
#          [0.03937008]],
#
#         ...,
#
#         [[0.03149606],
#          [0.03543307],
#          [0.03149606],
#          ...,
#          [0.03937008],
#          [0.04330709],
#          [0.05905512]],
#
#         [[0.0511811 ],
#          [0.04724409],
#          [0.04330709],
#          ...,
#          [0.03937008],
#          [0.06299213],
#          [0.09055118]],
#
#         [[0.02755906],
#          [0.04330709],
#          [0.03543307],
#          ...,
#          [0.03937008],
#          [0.07874016],
#          [0.03543307]]],
#
#
#        [[[0.05928854],
#          [0.04347826],
#          [0.04347826],
#          ...,
#          [0.01581028],
#          [0.01581028],
#          [0.02766798]],
#
#         [[0.07114624],
#          [0.02371541],
#          [0.04347826],
#          ...,
#          [0.01581028],
#          [0.00395257],
#          [0.02766798]],
#
#         [[0.05928854],
#          [0.03952569],
#          [0.06719368],
#          ...,
#          [0.03557312],
#          [0.03162055],
#          [0.03162055]],
#
#         ...,
#
#         [[0.03162055],
#          [0.02766798],
#          [0.03162055],
#          ...,
#          [0.05928854],
#          [0.04347826],
#          [0.04743083]],
#
#         [[0.04347826],
#          [0.03162055],
#          [0.01581028],
#          ...,
#          [0.03162055],
#          [0.06719368],
#          [0.10671937]],
#
#         [[0.04347826],
#          [0.03952569],
#          [0.05533597],
#          ...,
#          [0.02766798],
#          [0.06324111],
#          [0.03557312]]],
#
#
#        [[[0.07114624],
#          [0.03557312],
#          [0.04743083],
#          ...,
#          [0.03557312],
#          [0.00395257],
#          [0.02371541]],
#
#         [[0.05533597],
#          [0.03557312],
#          [0.04743083],
#          ...,
#          [0.01581028],
#          [0.00790514],
#          [0.03952569]],
#
#         [[0.05533597],
#          [0.04743083],
#          [0.07509881],
#          ...,
#          [0.04347826],
#          [0.03557312],
#          [0.02371541]],
#
#         ...,
#
#         [[0.04347826],
#          [0.02766798],
#          [0.02766798],
#          ...,
#          [0.03952569],
#          [0.04743083],
#          [0.04347826]],
#
#         [[0.03952569],
#          [0.00790514],
#          [0.00790514],
#          ...,
#          [0.04743083],
#          [0.06324111],
#          [0.09881423]],
#
#         [[0.02371541],
#          [0.03557312],
#          [0.03557312],
#          ...,
#          [0.01976285],
#          [0.07905138],
#          [0.03952569]]]])}
# 44423
# 68
# 68
# 1
# 2296
# 68
# 68
# 1
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# starting training F2 2024-10-30_08-59-10
# Epoch 1/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - loss: 0.0101 - val_loss: 0.0045
# Epoch 2/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 3/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 4/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 5/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 6/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 7/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 8/100
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0029 - val_loss: 0.0041
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_9 (TimeDistributed) │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_10                  │ (None, 10, 575)             │         331,200 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_11                  │ (None, 10, 575)             │         331,200 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_9 (TimeDistributed) │ (None, 10, 575)             │          14,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_10                  │ (None, 10, 575)             │         331,200 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_11                  │ (None, 10, 575)             │         331,200 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ (None, 10, 575)             │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 575)                 │       2,647,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 4624)                │       2,663,424 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,906,124 (98.82 MB)
#  Trainable params: 8,635,374 (32.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,270,750 (65.88 MB)
# None
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# 0.003542302968431925

# %%
def mri2vid(mri_data, dir_file, filename_no_ext, n_width, n_height, FramesPerSec):
    print(filename_no_ext + ' - MRI video started')
    output_file_no_ext = dir_file + filename_no_ext
    n_frames = len(mri_data)

    # Uncompressed 8-bit (use cv2.VideoWriter_fourcc instead of just VideoWriter_fourcc)
    fourcc = cv2.VideoWriter_fourcc(*'Y800')
    video = cv2.VideoWriter(output_file_no_ext + '.avi', fourcc, float(FramesPerSec), (n_width, n_height), 0)

    for n in range(n_frames):
        frame = np.uint8(255 * mri_data[n]).reshape(n_width, n_height, 1)
        video.write(frame)
        print('frame ', n, ' done', end='\r')

    video.release()
    print(filename_no_ext + ' - MRI video finished')

mri_data = y_pred
# mri2vid(mri_data, dir_mri_test, basefilename_name_only, n_width, n_height, framesPerSec)
# mrividwav2demo(dir_mri_test, basefilename_name_only + '.avi', os.path.dirname(dir_mri_wav) + '/', os.path.basename(dir_mri_wav))
dir_mri_test = '/content/drive/MyDrive/GAN_based_models/speech2mri/temp_outputs/'
basefilename_name_only = 'temp_file'
mri2vid(mri_data, dir_mri_test, basefilename_name_only, n_width, n_height, framesPerSec)
# Out:
# temp_file - MRI video started
# temp_file - MRI video finished
